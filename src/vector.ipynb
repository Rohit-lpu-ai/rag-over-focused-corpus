# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (1.5.9)
# Requirement already satisfied: build>=1.0.3 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (2.14.2)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.49.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (2.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (4.68.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (1.81.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from build>=1.0.3->chromadb) (26.2)
# Requirement already satisfied: pyproject_hooks in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from httpx>=0.27.0->chromadb) (4.14.1)
# Requirement already satisfied: certifi in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from httpx>=0.27.0->chromadb) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from httpx>=0.27.0->chromadb) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.34.2)
# Requirement already satisfied: requests-oauthlib in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: flatbuffers in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.35.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.43.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-proto==1.43.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.64b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.21.0)
# Requirement already satisfied: click>=8.4.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Users\DELL\Desktop\RAG focused corpus\.venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)

# %%
import pickle
from pathlib import Path

with open(Path("../data/processed/chunks.pkl"), "rb") as f:
    chunks = pickle.load(f)

with open(Path("../data/processed/embeddings.pkl"), "rb") as f:
    embeddings = pickle.load(f)

print(len(chunks), len(embeddings))
# Out:
# 103 103

# %%
import chromadb

client = chromadb.Client()

collection = client.create_collection(
    name="studybuddy_rag"
)

# %%
collection.add(
    ids=[str(i) for i in range(len(chunks))],
    embeddings=embeddings.tolist(),
    documents=[chunk["text"] for chunk in chunks],
    metadatas=[
        {
            "source": chunk["source"],
            "chunk_id": chunk["chunk_id"]
        }
        for chunk in chunks
    ]
)

print("Stored embeddings in ChromaDB")
# Out:
# Stored embeddings in ChromaDB

# %%
print(collection.count())
# Out:
# 103
