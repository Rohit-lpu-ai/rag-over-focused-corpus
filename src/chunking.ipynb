# %%
import sys
import subprocess

subprocess.check_call([sys.executable, "-m", "pip", "install", "langchain-text-splitters"])
# Out:
# Collecting langchain-text-splitters
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting langchain-core<2.0.0,>=1.2.31 (from langchain-text-splitters)
#   Using cached langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached langsmith-0.9.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.2)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading uuid_utils-0.16.2-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting anyio>=3.5.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached anyio-4.14.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro>=1.7.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting sniffio>=1.1 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting websockets>=15.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading xxhash-3.8.0-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting certifi (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading pydantic_core-2.46.4-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached langchain_core-1.4.8-py3-none-any.whl (557 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.9.3-py3-none-any.whl (619 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.3 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.16.2-cp313-cp313-win_amd64.whl (173 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.14.1-py3-none-any.whl (124 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl (127 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl (158 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached certifi-2026.6.17-py3-none-any.whl (133 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Downloading xxhash-3.8.0-cp313-cp313-win_amd64.whl (32 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, urllib3, typing-inspection, tenacity, sniffio, pyyaml, pydantic-core, orjson, langchain-protocol, jsonpointer, idna, h11, distro, charset_normalizer, certifi, annotated-types, requests, pydantic, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langchain-core, langchain-text-splitters
#
#    ----------------------------------------  0/29 [zstandard]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    ----- ----------------------------------  4/29 [urllib3]
#    ----- ----------------------------------  4/29 [urllib3]
#    ----- ----------------------------------  4/29 [urllib3]
#    ----- ----------------------------------  4/29 [urllib3]
#    ----- ----------------------------------  4/29 [urllib3]
#    ------ ---------------------------------  5/29 [typing-inspection]
#    -------- -------------------------------  6/29 [tenacity]
#    ----------- ----------------------------  8/29 [pyyaml]
#    ----------- ----------------------------  8/29 [pyyaml]
#    ----------- ----------------------------  8/29 [pyyaml]
#    ------------- -------------------------- 10/29 [orjson]
#    ---------------- ----------------------- 12/29 [jsonpointer]
#    ----------------- ---------------------- 13/29 [idna]
#    ------------------- -------------------- 14/29 [h11]
#    ------------------- -------------------- 14/29 [h11]
#    -------------------- ------------------- 15/29 [distro]
#    ---------------------- ----------------- 16/29 [charset_normalizer]
#    ---------------------- ----------------- 16/29 [charset_normalizer]
#    ------------------------ --------------- 18/29 [annotated-types]
#    -------------------------- ------------- 19/29 [requests]
#    -------------------------- ------------- 19/29 [requests]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    --------------------------- ------------ 20/29 [pydantic]
#    ---------------------------- ----------- 21/29 [jsonpatch]
#    ------------------------------ --------- 22/29 [httpcore]
#    ------------------------------ --------- 22/29 [httpcore]
#    ------------------------------ --------- 22/29 [httpcore]
#    ------------------------------ --------- 22/29 [httpcore]
#    ------------------------------- -------- 23/29 [anyio]
#    ------------------------------- -------- 23/29 [anyio]
#    ------------------------------- -------- 23/29 [anyio]
#    ------------------------------- -------- 23/29 [anyio]
#    ------------------------------- -------- 23/29 [anyio]
#    --------------------------------- ------ 24/29 [requests-toolbelt]
#    --------------------------------- ------ 24/29 [requests-toolbelt]
#    --------------------------------- ------ 24/29 [requests-toolbelt]
#    --------------------------------- ------ 24/29 [requests-toolbelt]
#    ---------------------------------- ----- 25/29 [httpx]
#    ---------------------------------- ----- 25/29 [httpx]
#    ---------------------------------- ----- 25/29 [httpx]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langsmith]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-core]
#    -------------------------------------- - 28/29 [langchain-text-splitters]
#    -------------------------------------- - 28/29 [langchain-text-splitters]
#    ---------------------------------------- 29/29 [langchain-text-splitters]
#
# Successfully installed annotated-types-0.7.0 anyio-4.14.1 certifi-2026.6.17 charset_normalizer-3.4.7 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jsonpatch-1.33 jsonpointer-3.1.1 langchain-core-1.4.8 langchain-protocol-0.0.18 langchain-text-splitters-1.1.2 langsmith-0.9.3 orjson-3.11.9 pydantic-2.13.4 pydantic-core-2.46.4 pyyaml-6.0.3 requests-2.34.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 urllib3-2.7.0 uuid-utils-0.16.2 websockets-16.0 xxhash-3.8.0 zstandard-0.25.0
#   WARNING: The script websockets.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script idna.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().resolve()))

from ingest import load_documents
from langchain_text_splitters import RecursiveCharacterTextSplitter


docs = load_documents()
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100,
    length_function=len,
)

chunks = []

for doc in docs:
    split_chunks = text_splitter.split_text(doc["text"])

    for idx, chunk in enumerate(split_chunks):
        chunks.append({
            "source": doc["filename"],
            "chunk_id": idx,
            "text": chunk,
        })

print(f"Created {len(chunks)} chunks")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       7 )
#       8
#       9 chunks = []
#      10
# ---> 11 for doc in docs:
#      12     split_chunks = text_splitter.split_text(doc["text"])
#      13
#      14     for idx, chunk in enumerate(split_chunks):
#
# NameError: name 'docs' is not defined

# %%
docs = load_documents()
print(f"Loaded {len(docs)} documents")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 docs = load_documents()
#       2 print(f"Loaded {len(docs)} documents")
#
# NameError: name 'load_documents' is not defined

# %%
from pathlib import Path
from pypdf import PdfReader

# %%
docs = load_documents()
print(f"Loaded {len(docs)} documents")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 docs = load_documents()
#       2 print(f"Loaded {len(docs)} documents")
#
# NameError: name 'load_documents' is not defined
